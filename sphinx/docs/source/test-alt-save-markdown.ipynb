# %% [markdown]
# # Save + Markdown Test

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0.0, 2.0 * np.pi, 100)

# %%
fig, ax = plt.subplots()
ax.plot(x, np.sin(x))
fig.savefig("test-md.png")
plt.close(fig)

# %% [markdown]
# ![alt test](test-md.png)
